# %%
import numpy as np
import pandas as pd
#from pandas_datareader import data as wb
import matplotlib.pyplot as plt

# %%
import yfinance as yf
Data = pd.DataFrame()
#define the ticker symbol
tickerSymbol =[ "XAUUSD"]#, "CL=F"] # "GOLD"
n=0
for t in tickerSymbol:
    #get data on this ticker
    tickerData = yf.Ticker(tickerSymbol[n])
    #get the historical prices for this ticker
    Data[t] = tickerData.history(interval='1mo', start='2015-01-01', end='2022-05-01')['Close']
    n=n+1
Data
# Out:
# - XAUUSD: No data found, symbol may be delisted
# Empty DataFrame
# Columns: [XAUUSD]
# Index: []

# %%
Data.to_csv("Gold-XAU.csv")

# %%
pip install yfinance
# Out:
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000027384B88C40>, 'Connection to files.pythonhosted.org timed out. (connect timeout=15)')': /packages/a1/b5/bf3bf6adf9acdd18ac15f93e2d42b7a9a468f8cb70144e316980d9d9dd61/yfinance-0.1.70-py2.py3-none-any.whl
# ...
#      ---------------------------------------- 3.6/3.6 MB 511.4 kB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
# Using legacy 'setup.py install' for multitasking, since package 'wheel' is not installed.
# ...
#   Running setup.py install for multitasking: started
#   Running setup.py install for multitasking: finished with status 'done'
# ...
# WARNING: You are using pip version 22.0.1; however, version 22.1 is available.
# ...

# %%
import yfinance as yf
Data = pd.DataFrame()
#define the ticker symbol
tickerSymbol =["BTC-USD" , "ETH-USD" , "XRP-USD" , "SOL-USD" , "LUNA1-USD" , "ADA-USD" , "AVAX-USD" , "DOT-USD" , "DOGE-USD" , "MATIC-USD"]
#tickerSymbol = ['X', 'CLF', 'ABEV', 'KGC']
n=0
for t in tickerSymbol:
    #get data on this ticker
    tickerData = yf.Ticker(tickerSymbol[n])
    #get the historical prices for this ticker
    Data[t] = tickerData.history(period='1d', start='2021-01-01', end='2022-01-01')['Close']
    n=n+1
Data
#Data.to_csv("Data_crypto.csv")
# Out:
#                  BTC-USD      ETH-USD   XRP-USD     SOL-USD  LUNA1-USD  \
# Date
# 2020-12-31  29001.720703   737.803406  0.219846    1.510898   0.652520
# 2021-01-01  29374.152344   730.367554  0.237444    1.842084   0.649443
# 2021-01-02  32127.267578   774.534973  0.221655    1.799275   0.631426
# 2021-01-03  32782.023438   975.507690  0.225848    2.161752   0.661895
# 2021-01-04  31971.914062  1040.233032  0.236677    2.485097   0.670244
# ...                  ...          ...       ...         ...        ...
# 2021-12-27  50640.417969  4037.547607  0.926184  195.429504  90.800499
# 2021-12-28  47588.855469  3800.893066  0.852960  177.425629  85.368347
# 2021-12-29  46444.710938  3628.531738  0.816714  170.657562  84.059334
# 2021-12-30  47178.125000  3713.852051  0.839649  172.751190  84.711868
# 2021-12-31  46306.445312  3682.632812  0.831163  170.299072  85.472542
#
#              ADA-USD    AVAX-USD    DOT-USD  DOGE-USD  MATIC-USD
# Date
# ...

# %%
Data.to_csv("Data_crypto.csv")

# %%
#6 mounths
import yfinance as yf
Data6 = pd.DataFrame()
#define the ticker symbol
tickerSymbol =["BTC-USD" , "ETH-USD" , "XRP-USD" , "SOL-USD" , "LUNA1-USD" , "ADA-USD" , "AVAX-USD" , "DOT-USD" , "DOGE-USD" , "MATIC-USD"]
#tickerSymbol = ['X', 'CLF', 'ABEV', 'KGC']
n=0
for t in tickerSymbol:
    #get data on this ticker
    tickerData = yf.Ticker(tickerSymbol[n])
    #get the historical prices for this ticker
    Data6[t] = tickerData.history(period='1d', start='2021-11-01', end='2022-05-01')['Close']
    n=n+1
Data6
# Out:
#                  BTC-USD      ETH-USD   XRP-USD     SOL-USD  LUNA1-USD  \
# Date
# 2021-10-31  61318.957031  4288.074219  1.113247  202.421021  42.889774
# 2021-11-01  61004.406250  4324.626953  1.092867  203.545090  44.059307
# 2021-11-02  63226.402344  4584.798828  1.136196  220.239594  44.755489
# 2021-11-03  62970.046875  4607.193848  1.208796  242.898819  48.061790
# 2021-11-04  61452.230469  4537.324219  1.202003  247.387772  51.922386
# ...                  ...          ...       ...         ...        ...
# 2022-04-26  38117.460938  2808.298340  0.641699   95.782150  88.550468
# 2022-04-27  39241.121094  2888.929688  0.652318   98.378868  89.090111
# 2022-04-28  39773.828125  2936.940918  0.644363   98.185730  88.961685
# 2022-04-29  38609.824219  2815.601807  0.611407   94.011345  85.116302
# 2022-04-30  37714.875000  2730.186768  0.587091   85.095932  78.344093
#
#              ADA-USD   AVAX-USD    DOT-USD  DOGE-USD  MATIC-USD
# Date
# ...

# %%
Data6.to_csv("Data_crypto_6_month.csv")

# %%
import yfinance as yf
Dataq3 = pd.DataFrame()
#define the ticker symbol
tickerSymbol =["BTC-USD" , "ETH-USD" , "XRP-USD"]
#tickerSymbol = ['X', 'CLF', 'ABEV', 'KGC']
n=0
for t in tickerSymbol:
    #get data on this ticker
    tickerData = yf.Ticker(tickerSymbol[n])
    #get the historical prices for this ticker
    Dataq3[t] = tickerData.history(period='1d', start='2021-01-01', end='2022-01-01')['Close']
    n=n+1
Dataq3
# Out:
#                  BTC-USD      ETH-USD   XRP-USD
# Date
# 2020-12-31  29001.720703   737.803406  0.219846
# 2021-01-01  29374.152344   730.367554  0.237444
# 2021-01-02  32127.267578   774.534973  0.221655
# 2021-01-03  32782.023438   975.507690  0.225848
# 2021-01-04  31971.914062  1040.233032  0.236677
# ...                  ...          ...       ...
# 2021-12-27  50640.417969  4037.547607  0.926184
# 2021-12-28  47588.855469  3800.893066  0.852960
# 2021-12-29  46444.710938  3628.531738  0.816714
# 2021-12-30  47178.125000  3713.852051  0.839649
# 2021-12-31  46306.445312  3682.632812  0.831163
#
# [366 rows x 3 columns]

# %%
Dataq3.to_csv("Data_crypto_q3.csv")

# %%
#Bitcoin
import yfinance as yf
Data_bitcoin = pd.DataFrame()
#define the ticker symbol

n=0

tickerData = yf.Ticker("BTC-USD")
#get the historical prices for this ticker
Data_bitcoin["BTC-USD"] = tickerData.history(period='1d', start='2021-05-01', end='2022-05-01')['Close']
n=n+1
Data_bitcoin
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21788/239745893.py in <module>
#       1 #Bitcoin
#       2 import yfinance as yf
# ----> 3 Data_bitcoin = pd.DataFrame()
#       4 #define the ticker symbol
#       5
#
# NameError: name 'pd' is not defined

# %%
Data_bitcoin.to_csv("Data_Bitcoin.csv")

# %%
#3 year

import yfinance as yf
Data = pd.DataFrame()
#define the ticker symbol
tickerSymbol =["BTC-USD" , "ETH-USD" , "XRP-USD" , "ADA-USD" , "DOGE-USD"]
#tickerSymbol = ['X', 'CLF', 'ABEV', 'KGC']
n=0
for t in tickerSymbol:
    #get data on this ticker
    tickerData = yf.Ticker(tickerSymbol[n])
    #get the historical prices for this ticker
    Data[t] = tickerData.history(period='1d', start='2019-05-01', end='2022-05-01')['Close']
    n=n+1
Data
# Out:
#                  BTC-USD      ETH-USD   XRP-USD   ADA-USD  DOGE-USD
# Date
# 2019-04-30   5350.726562   162.166031  0.309476  0.070346  0.002513
# 2019-05-01   5402.697266   160.818344  0.304696  0.069014  0.002521
# 2019-05-02   5505.283691   162.122787  0.303239  0.068579  0.002611
# 2019-05-03   5768.289551   167.952408  0.308222  0.069858  0.002721
# 2019-05-04   5831.167480   164.026581  0.304552  0.066880  0.002680
# ...                  ...          ...       ...       ...       ...
# 2022-04-26  38117.460938  2808.298340  0.641699  0.827645  0.137767
# 2022-04-27  39241.121094  2888.929688  0.652318  0.840595  0.139700
# 2022-04-28  39773.828125  2936.940918  0.644363  0.843950  0.137363
# 2022-04-29  38609.824219  2815.601807  0.611407  0.805043  0.135027
# 2022-04-30  37714.875000  2730.186768  0.587091  0.756660  0.127557
#
# [1097 rows x 5 columns]

# %%
Data.to_csv("Data_3_year.csv")
